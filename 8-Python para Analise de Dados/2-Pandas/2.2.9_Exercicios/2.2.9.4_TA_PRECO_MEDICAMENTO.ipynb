# %% [markdown]
# Os dados representam a lista de preços de Medicamentos , contemplando o preço Fábrica, ou preço fabricante (PF), que é o preço máximo que pode ser praticado pelas empresas produtoras ou importadoras do produto e pelas empresas distribuidoras. O PF indica o preço máximo permitido para venda a farmácias e drogarias e o Preço Máximo ao Consumidor (PMC) indica o preço teto de venda ao consumidor.
#
#
# http://dados.gov.br/dataset/anvisa-precos-de-medicamentos-consumidor

# %%
import pandas as pd

# %%
ta_preco_medicamento = pd.read_csv("CSV/TA_PRECO_MEDICAMENTO.csv", sep=';', encoding='ISO-8859-1')

# %%
ta_preco_medicamento.head()
# Out:
#                                 SUBSTï¿½NCIA                CNPJ  \
# 0                        CEFALOTINA Sï¿½DICA  04.301.884/0001-75
# 1                        CEFAZOLINA Sï¿½DICA  04.301.884/0001-75
# 2                        CEFOTAXIMA Sï¿½DICA  04.301.884/0001-75
# 3  CLORIDRATO DE CIPROFLOXACINO MONOIDRATADO  04.301.884/0001-75
# 4                                 CEFALEXINA  04.301.884/0001-75
#
#                                        LABORATï¿½RIO   Cï¿½DIGO GGREM  \
# 0  AUROBINDO PHARMA INDï¿½STRIA FARMACï¿½UTICA LI...  500100106155118
# 1  AUROBINDO PHARMA INDï¿½STRIA FARMACï¿½UTICA LI...  500100204157115
# 2  AUROBINDO PHARMA INDï¿½STRIA FARMACï¿½UTICA LI...  500100310151117
# 3  AUROBINDO PHARMA INDï¿½STRIA FARMACï¿½UTICA LI...  500100410113111
# 4  AUROBINDO PHARMA INDï¿½STRIA FARMACï¿½UTICA LI...  500100801112111
#
#         REGISTRO          EAN 1  EAN 2  EAN 3                       PRODUTO  \
# 0  1516700060050  7898361881450    NaN    NaN           CEFALOTINA Sï¿½DICA
# 1  1516700030038  7898361881405    NaN    NaN           CEFAZOLINA Sï¿½DICA
# 2  1516700050063  7898361881412    NaN    NaN           CEFOTAXIMA Sï¿½DICA
# 3  1516700070099  7898361881313    NaN    NaN  CLORIDRATO DE CIPROFLOXACINO
# 4  1516700080035  7898361880019    NaN    NaN                    CEFALEXINA
#
#                                  APRESENTAï¿½ï¿½O  ... PMC 18% ALC PMC 20%  \
# 0   1G Pï¿½ P/ SOL INJ CT 50 FA VD INC (EMB HOSP)  ...         NaN     NaN
# 1  1 G Pï¿½ P/ SOL INJ CT 50 FA VD INC (EMB HOSP)  ...         NaN     NaN
# 2  1 G Pï¿½ P/ SOL INJ CT 50 FA VD INC (EMB HOSP)  ...         NaN     NaN
# 3         500 MG COM REV CT 2 BL AL PLAS INC X 07  ...       36,93   37,85
# 4        500 MG COM REV CT BL AL PVC/PVDC INC X 8  ...       16,76   17,17
#
#   RESTRIï¿½ï¿½O HOSPITALAR    CAP CONFAZ 87 ICMS 0% ANï¿½LISE RECURSAL  \
# 0                      Sim  Nï¿½o     Nï¿½o   Nï¿½o                NaN
# 1                      Sim  Nï¿½o     Nï¿½o   Nï¿½o                NaN
# 2                      Sim  Nï¿½o     Nï¿½o   Nï¿½o                NaN
# 3                    Nï¿½o  Nï¿½o       Sim   Nï¿½o                NaN
# 4                    Nï¿½o  Nï¿½o     Nï¿½o   Nï¿½o                NaN
#
#   LISTA DE CONCESSï¿½O DE CRï¿½DITO TRIBUTï¿½RIO (PIS/COFINS)  \
# 0                                           POSITIVA
# 1                                           POSITIVA
# 2                                           POSITIVA
# 3                                           POSITIVA
# 4                                           POSITIVA
#
#   COMERCIALIZAï¿½ï¿½O 2018           TARJA
# 0                      Sim  Tarja Vermelha
# 1                      Sim  Tarja Vermelha
# 2                      Sim  Tarja Vermelha
# 3                      Sim  Tarja Vermelha
# 4                      Sim  Tarja Vermelha
#
# [5 rows x 40 columns]
