# %% [markdown]
# # Covid19
#
# Os dados foram obtidos de https://data.brasil.io/dataset/covid19/_meta/list.html

# %%
import numpy as np
import pandas as pd
boletimarq='CSV/boletim.csv.gz'
boletim = pd.read_csv(boletimarq, compression='gzip')
boletim
# Out:
#             date state                                                url  \
# 0     2020-03-14    SE               https://www.saude.se.gov.br/?p=39206
# 1     2020-03-16    SE               https://www.saude.se.gov.br/?p=39252
# 2     2020-03-18    SE               https://www.saude.se.gov.br/?p=39298
# 3     2020-03-20    SE               https://www.saude.se.gov.br/?p=39368
# 4     2020-03-21    SE               https://www.saude.se.gov.br/?p=39380
# 5     2020-03-24    SE               https://www.saude.se.gov.br/?p=39418
# 6     2020-03-25    SE               https://www.saude.se.gov.br/?p=39482
# 7     2020-03-27    SE               https://www.saude.se.gov.br/?p=39526
# 8     2020-03-30    SE               https://www.saude.se.gov.br/?p=39588
# 9     2020-03-31    SE               https://www.saude.se.gov.br/?p=39600
# 10    2020-04-01    SE               https://www.saude.se.gov.br/?p=39639
# 11    2020-04-02    SE               https://www.saude.se.gov.br/?p=39654
# ...

# %%
url="https://data.brasil.io/dataset/covid19/boletim.csv.gz"
boletim=pd.read_csv(url, compression='gzip')
boletim
# Out:
#             date state                                                url  \
# 0     2020-03-14    SE               https://www.saude.se.gov.br/?p=39206
# 1     2020-03-16    SE               https://www.saude.se.gov.br/?p=39252
# 2     2020-03-18    SE               https://www.saude.se.gov.br/?p=39298
# 3     2020-03-20    SE               https://www.saude.se.gov.br/?p=39368
# 4     2020-03-21    SE               https://www.saude.se.gov.br/?p=39380
# 5     2020-03-24    SE               https://www.saude.se.gov.br/?p=39418
# 6     2020-03-25    SE               https://www.saude.se.gov.br/?p=39482
# 7     2020-03-27    SE               https://www.saude.se.gov.br/?p=39526
# 8     2020-03-30    SE               https://www.saude.se.gov.br/?p=39588
# 9     2020-03-31    SE               https://www.saude.se.gov.br/?p=39600
# 10    2020-04-01    SE               https://www.saude.se.gov.br/?p=39639
# 11    2020-04-02    SE               https://www.saude.se.gov.br/?p=39654
# ...

# %%
casoarq='CSV/caso.csv.gz'
caso=pd.read_csv(casoarq, compression='gzip')
caso
# Out:
#              date state         city place_type  confirmed  deaths  \
# 0      2020-05-15    SE          NaN      state       2868      50
# 1      2020-05-14    SE          NaN      state       2494      47
# 2      2020-05-13    SE          NaN      state       2268      42
# 3      2020-05-12    SE          NaN      state       2032      37
# 4      2020-05-11    SE          NaN      state       1800      37
# 5      2020-05-10    SE          NaN      state       1771      34
# 6      2020-05-09    SE          NaN      state       1588      33
# 7      2020-05-08    SE          NaN      state       1438      28
# 8      2020-05-07    SE          NaN      state       1214      25
# 9      2020-05-06    SE          NaN      state        998      23
# 10     2020-05-05    SE          NaN      state        898      21
# 11     2020-05-04    SE          NaN      state        772      17
# 12     2020-05-03    SE          NaN      state        730      14
# ...

# %%
'casos confirmados {} números de mortes {}'.format(caso['confirmed'].mean(), caso['deaths'].mean())
# Out:
# 'casos confirmados 81.01344390585761 números de mortes 5.37960637738714'

# %%
casofullarq='CSV/caso_full.csv.gz'
caso_full=pd.read_csv(casofullarq, compression='gzip')
caso_full
# Out:
#                    city  city_ibge_code        date  epidemiological_week  \
# 0             São Paulo       3550308.0  2020-02-25                     9
# 1                   NaN            35.0  2020-02-25                     9
# 2             São Paulo       3550308.0  2020-02-26                     9
# 3                   NaN            35.0  2020-02-26                     9
# 4             São Paulo       3550308.0  2020-02-27                     9
# 5                   NaN            35.0  2020-02-27                     9
# 6             São Paulo       3550308.0  2020-02-28                     9
# 7                   NaN            35.0  2020-02-28                     9
# 8             São Paulo       3550308.0  2020-02-29                     9
# 9                   NaN            35.0  2020-02-29                     9
# 10            São Paulo       3550308.0  2020-03-01                    10
# 11                  NaN            35.0  2020-03-01                    10
# ...

# %%
obito_cartorioarq='CSV/obito_cartorio.csv.gz'
obito_cartorio=pd.read_csv(obito_cartorioarq, compression='gzip')
obito_cartorio
# Out:
#             date state  epidemiological_week_2019  epidemiological_week_2020  \
# 0     2020-01-01    AC                          1                          1
# 1     2020-01-02    AC                          1                          1
# 2     2020-01-03    AC                          1                          1
# 3     2020-01-04    AC                          1                          1
# 4     2020-01-05    AC                          1                          2
# 5     2020-01-06    AC                          2                          2
# 6     2020-01-07    AC                          2                          2
# 7     2020-01-08    AC                          2                          2
# 8     2020-01-09    AC                          2                          2
# 9     2020-01-10    AC                          2                          2
# 10    2020-01-11    AC                          2                          2
# ...
